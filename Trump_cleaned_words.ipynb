# %% [markdown]
# <a href="https://colab.research.google.com/github/HelenNunez/BALG_Project3/blob/master/Trump_cleaned_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow

# %%
pip install --upgrade tensorflow-datasets

# %%
pip install -q tensorflow>=2 tfds-nightly matplotlib

# %%
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds 
import pandas as pd
import re
from wordcloud import WordCloud, STOPWORDS
from IPython.display import Image as im

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATASET_NAME = '/content/drive/My\ Drive/BALG_GoogleDriveLN'

# %%
print(DATASET_NAME)
# Out:
# /content/drive/My\ Drive/BALG_GoogleDriveLN

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !cp /content/drive/My\ Drive/BALG_GoogleDriveLN -r /content

# %%
text_df = 'BALG_GoogleDriveLN/trump_words.csv'
text_df = pd.read_csv(text_df) 
text_df
# Out:
#        Unnamed: 0                                              Words
# 0               0  ['well', 'would', 'nice', 'quoted', 'whole', '...
# 1               1  ['yeah', 'i', 'sure', '//www-gq-com.cdn.amppro...
# 2               2  ['//www.insider.com/donald-trump-jeffrey-epste...
# 3               3  ['then', 'protesters', 'every', 'right', 'defe...
# 4               4  ['truth', '//time.com/4465744/donald-trump-und...
# ...           ...                                                ...
# 84735       84735  ['subreddit', 'pro-trump', 'subreddit', 'shari...
# 84736       84736  ['if', 'people', 'think', 'politicians', 'corr...
# 84737       84737  ['subreddit', 'pro-trump', 'subreddit', 'shari...
# 84738       84738  ['subreddit', 'pro-trump', 'subreddit', 'shari...
# 84739       84739  ['i', 'heard', 'donald', 'trump', 'going', 'ra...
#
# [84740 rows x 2 columns]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
full_text = text_df["Words"]

# %%
raw_string = ''.join(full_text)
no_links = re.sub(r'http\S+', '', raw_string)
no_unicode = re.sub(r"\\[a-z][a-z]?[0-9]+", '', no_links)
no_special_characters = re.sub('[^A-Za-z ]+', '', no_unicode)
words = no_special_characters.split(" ")
words = [w for w in words if len(w) > 2]
words = [w.lower() for w in words]
words = [w for w in words if w not in STOPWORDS]
words
# Out:
# ['well',
#  'nice',
#  'quoted',
#  'whole',
#  'story',
#  'act',
#  'disingenuous',
#  'thats',
#  'literally',
#  'entire',
#  'interview',
#  'point',
#  'need',
#  'something',
#  'outside',
#  'said',
#  'try',
#  'argue',
#  'said',
#  'hypothetical',
#  'question',
#  'hypothetical',
#  'question',
#  'yes',
#  'really',
#  'simple',
#  'trump',
#  'recommendation',
#  'yes',
#  'situation',
#  'hypothetical',
#  'recommendation',
#  'point',
#  'holt',
#  'imply',
#  'recommendation',
#  'following',
#  'exchange',
#  'donald',
#  'trump',
#  'look',
#  'show',
#  'boat',
#  'grand',
#  'stander',
#  'fbi',
#  'turmoil',
#  'know',
#  'know',
#  'everybody',
#  'knows',
#  'take',
#  'look',
#  'fbi',
#  'year',
#  'ago',
#  'virtual',
#  'turmoil',
#  'less',
#  'year',
#  'ago',
#  'recovered',
#  'lester',
#  'holt',
#  'monday',
#  'met',
#  'deputy',
#  'attorney',
#  'geneal',
#  'rod',
#  'rosen',
#  'rosenstein',
#  'donald',
#  'trump',
#  'right',
#  'lester',
# ...

# %%
text_df = pd.DataFrame({"words":words})
text_df
text_df.to_csv('/content/Cleaned_trump_words_SR.csv')

# %%
Biden_text_df = 'BALG_GoogleDriveLN/biden_words.csv'
Biden_text_df = pd.read_csv(Biden_text_df) 
Biden_text_df
# Out:
#          Unnamed: 0       Words
# 0                 0         joe
# 1                 1       biden
# 2                 2         bad
# 3                 3  conspiracy
# 4                 4        said
# ...             ...         ...
# 2911454     2911454        need
# 2911455     2911455       stick
# 2911456     2911456      brunch
# 2911457     2911457        smug
# 2911458     2911458    articles
#
# [2911459 rows x 2 columns]

# %%
#Biden_text_df["Words"] = Biden_text_df['Words'].astype(str)

# %%
Biden_full_text = Biden_text_df['Words']
Biden_full_text

# %%
raw_string = ''.join(Biden_full_text)
no_links = re.sub(r'http\S+', '', raw_string)
no_unicode = re.sub(r"\\[a-z][a-z]?[0-9]+", '', no_links)
no_special_characters = re.sub('[^A-Za-z ]+', '', no_unicode)
words = no_special_characters.split(" ")
words = [w for w in words if len(w) > 2]
words = [w.lower() for w in words]
words = [w for w in words if w not in STOPWORDS]
words
# Out:
# ['...']

# %%
Biden_text_df = pd.DataFrame({"words":words})
Biden_text_df
Biden_text_df.to_csv('/content/Cleaned_biden_words_SR.csv')
