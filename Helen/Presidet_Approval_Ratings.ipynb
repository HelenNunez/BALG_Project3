# %%
import pandas as pd
import numpy as np

# %%
DataSet2 = "president_approval_polls.csv"
DataSet2 = pd.read_csv(DataSet2)
DataSet2
# Out:
#       question_id  poll_id  state  politician_id    politician  pollster_id  \
# 0          127664    68159    NaN             11  Donald Trump          568
# 1          127665    68159    NaN             11  Donald Trump          568
# 2          127666    68160    NaN             11  Donald Trump         1562
# 3          127634    68140    NaN             11  Donald Trump          568
# 4          127635    68140    NaN             11  Donald Trump          568
# ...           ...      ...    ...            ...           ...          ...
# 8902        77560    49426    NaN             11  Donald Trump          744
# 8903        77599    49426    NaN             11  Donald Trump          744
# 8904        77274    49262    NaN             11  Donald Trump          169
# 8905        77261    49249    NaN             11  Donald Trump         1189
# 8906        77265    49253    NaN             11  Donald Trump          169
#
# ...

# %%
President_Approvals = DataSet2[["sample_size", "population_full", "methodology", "candidate_name", "candidate_party", "pct"]]
President_Approvals
